# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import os
path=r'C:\Users\ANIL\Desktop\python\tree data structure'
os.chdir(path)

# %%
df=pd.read_csv('dataset123.csv')
df.head(30)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1     2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2     3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3     4.0      M  56.00      NaN  52.00  Central   Science     52.00
# 4     5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5     6.0      M  55.00   Others    NaN   Others   Science     67.25
# 6     NaN      F  46.00   Others  49.20   Others  Commerce     79.00
# 7     8.0      M  82.00  Central  64.00  Central   Science     66.00
# 8     9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 9     NaN      M  58.00      NaN  70.00  Central  Commerce     61.00
# 10   11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# 11   12.0      M  69.60  Central    NaN  Central  Commerce     78.30
# 12   13.0      F  47.00  Central  55.00   Others   Science       NaN
# ...

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  209.000000  215.000000  209.000000  213.000000  213.000000  212.000000
# mean   110.602871   67.303395   66.301100   66.415915   72.096808   62.248868
# std     61.123301   10.827205   10.949664    7.370247   13.331212    5.795673
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     59.000000   60.600000   60.800000   61.000000   60.000000   57.967500
# 50%    111.000000   67.000000   65.000000   66.000000   71.000000   61.950000
# 75%    163.000000   75.700000   73.000000   72.000000   84.000000   66.242500
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.dropna(axis=1)
# Out:
#     gender  ssc_p    hsc_b     hsc_s   degree_t
# 0        M  67.00   Others  Commerce   Sci&Tech
# 1        M  79.33   Others   Science   Sci&Tech
# 2        M  65.00  Central      Arts  Comm&Mgmt
# 3        M  56.00  Central   Science   Sci&Tech
# 4        M  85.80  Central  Commerce  Comm&Mgmt
# ..     ...    ...      ...       ...        ...
# 210      M  80.60   Others  Commerce  Comm&Mgmt
# 211      M  58.00   Others   Science   Sci&Tech
# 212      M  67.00   Others  Commerce  Comm&Mgmt
# 213      F  74.00   Others  Commerce  Comm&Mgmt
# 214      M  62.00   Others   Science  Comm&Mgmt
#
# [215 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl_no              6
# gender             0
# ssc_p              0
# ssc_b              6
# hsc_p              6
# hsc_b              0
# hsc_s              0
# degree_p           2
# degree_t           0
# workex             1
# etest_p            2
# specialisation     4
# mba_p              3
# status             3
# salary            67
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)

# %%
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 213
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           139 non-null    float64
#  1   gender          139 non-null    object
#  2   ssc_p           139 non-null    float64
#  3   ssc_b           139 non-null    object
#  4   hsc_p           139 non-null    float64
#  5   hsc_b           139 non-null    object
#  6   hsc_s           139 non-null    object
#  7   degree_p        139 non-null    float64
#  8   degree_t        139 non-null    object
#  9   workex          139 non-null    object
#  10  etest_p         139 non-null    float64
#  11  specialisation  139 non-null    object
#  12  mba_p           139 non-null    float64
#  13  status          139 non-null    object
#  14  salary          139 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 17.4+ KB

# %%
df.mean()
# Out:
# sl_no          112.431655
# ssc_p           71.770647
# hsc_p           69.609568
# degree_p        68.573453
# etest_p         73.380935
# mba_p           62.405324
# salary      288201.438849
# dtype: float64

# %%
def gender(x):
        if x=='F':
             return 1
        if x=='M':
             return 0

# %%
df['']=df['gender'].apply(gender)
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 7      8.0      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209  210.0      M  62.00  Central  72.00  Central  Commerce     65.00
# 210  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 211  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 212  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 213  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
df['ssc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['ssc_b']= label_encoder.fit_transform(df['ssc_b'])
df['ssc_b'].unique()
# Out:
# array([1, 0])

# %%
df['hsc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['hsc_b']= label_encoder.fit_transform(df['hsc_b'])
df['hsc_b'].unique()
# Out:
# array([1, 0])

# %%
df['degree_t'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['degree_t']= label_encoder.fit_transform(df['degree_t'])
df['degree_t'].unique()
# Out:
# array([2, 0, 1])

# %%
df['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['specialisation']= label_encoder.fit_transform(df['specialisation'])
df['specialisation'].unique()
# Out:
# array([1, 0])

# %%
df['status'].unique()
# Out:
# array(['Placed'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['status']= label_encoder.fit_transform(df['status'])
df['status'].unique()
# Out:
# array([0])

# %%
df['hsc_s'].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['hsc_s']= label_encoder.fit_transform(df['hsc_s'])
df['hsc_s'].unique()
# Out:
# array([1, 2, 0])

# %%
df['workex'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['workex']= label_encoder.fit_transform(df['workex'])
df['workex'].unique()
# Out:
# array([0, 1])

# %%
df
# Out:
#      sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1.0      M  67.00      1  91.00      1      1     58.00         2
# 1      2.0      M  79.33      0  78.33      1      2     77.48         2
# 2      3.0      M  65.00      0  68.00      0      0     64.00         0
# 4      5.0      M  85.80      0  73.60      0      1     73.30         0
# 7      8.0      M  82.00      0  64.00      0      2     66.00         2
# ..     ...    ...    ...    ...    ...    ...    ...       ...       ...
# 209  210.0      M  62.00      0  72.00      0      1     65.00         0
# 210  211.0      M  80.60      1  82.00      1      1     77.60         0
# 211  212.0      M  58.00      1  60.00      1      2     72.00         2
# 212  213.0      M  67.00      1  67.00      1      1     73.00         0
# 213  214.0      F  74.00      1  66.00      1      1     58.00         0
#
#      workex  etest_p  specialisation  mba_p  status    salary
# ...

# %%
df_age=pd.DataFrame(df['ssc_p'],columns=['ssc_p'],dtype=str)
df_age[df['ssc_p']<=101]='70 to 100'
df_age[df['ssc_p']<=70]='30 to 70'
df_age[df['ssc_p']<=30]='0 to 30'
df_age.head(10)
# Out:
#         ssc_p
# 0    30 to 70
# 1   70 to 100
# 2    30 to 70
# 4   70 to 100
# 7   70 to 100
# 8   70 to 100
# 10   30 to 70
# 16   30 to 70
# 19   30 to 70
# 23  70 to 100

# %%
df_age=pd.DataFrame(df['etest_p'],columns=['etest_p'],dtype=str)
df_age[df['etest_p']<=101]='70 to 100'
df_age[df['etest_p']<=70]='30 to 70'
df_age[df['etest_p']<=30]='0 to 30'
df_age.head(10)
# Out:
#       etest_p
# 0    30 to 70
# 1   70 to 100
# 2   70 to 100
# 4   70 to 100
# 7    30 to 70
# 8   70 to 100
# 10   30 to 70
# 16   30 to 70
# 19   30 to 70
# 23  70 to 100

# %%
print('mba_p\n',df_age.value_counts())
# Out:
# mba_p
#  etest_p
# 70 to 100    75
# 30 to 70     64
# dtype: int64

# %%
plt.pie([75,64],labels=['70 to 100','30 to 70'],autopct='%2.2f%%')
plt.title('MBA PERCENTAGE')
plt.show()

# %%
hsc_s_count=df['hsc_s'].value_counts()
print(hsc_s_count)
f=plt.figure()
f.set_figwidth(8)
f.set_figheight(4)
plt.bar(hsc_s_count.index,hsc_s_count.values)
plt.title('hsc_s')
plt.show()
# Out:
# 1    72
# 2    61
# 0     6
# Name: hsc_s, dtype: int64

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary', ''],
#       dtype='object')

# %%
cols=['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
       'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
       'salary']
X=df[cols]
y=df['status']
X.head()
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    1.0      M  67.00      1  91.00      1      1     58.00         2
# 1    2.0      M  79.33      0  78.33      1      2     77.48         2
# 2    3.0      M  65.00      0  68.00      0      0     64.00         0
# 4    5.0      M  85.80      0  73.60      0      1     73.30         0
# 7    8.0      M  82.00      0  64.00      0      2     66.00         2
#
#    workex  etest_p  specialisation  mba_p    salary
# 0       0     55.0               1  58.80  270000.0
# 1       1     86.5               0  66.28  200000.0
# 2       0     75.0               0  57.80  250000.0
# 4       0     96.8               0  55.50  425000.0
# 7       1     67.0               0  62.14  252000.0

# %%
df
# Out:
#      sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1.0      M  67.00      1  91.00      1      1     58.00         2
# 1      2.0      M  79.33      0  78.33      1      2     77.48         2
# 2      3.0      M  65.00      0  68.00      0      0     64.00         0
# 4      5.0      M  85.80      0  73.60      0      1     73.30         0
# 7      8.0      M  82.00      0  64.00      0      2     66.00         2
# ..     ...    ...    ...    ...    ...    ...    ...       ...       ...
# 209  210.0      M  62.00      0  72.00      0      1     65.00         0
# 210  211.0      M  80.60      1  82.00      1      1     77.60         0
# 211  212.0      M  58.00      1  60.00      1      2     72.00         2
# 212  213.0      M  67.00      1  67.00      1      1     73.00         0
# 213  214.0      F  74.00      1  66.00      1      1     58.00         0
#
#      workex  etest_p  specialisation  mba_p  status    salary
# ...

# %%
y[y=='drugY']=4
y[y=='drugC']=2
y[y=='drugX']=3
y[y=='drugA']=0
y[y=='drugB']=1
y=pd.to_numeric(y)
y

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=46,test_size=0.3)

# %%
y_train.dtypes
# Out:
# dtype('float64')

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
dc.fit(X_train,y_train)
predictions=dc.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-2d7e4b131f38> in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 dc=DecisionTreeClassifier()
# ----> 3 dc.fit(X_train,y_train)
#       4 predictions=dc.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-81150c318142> in <module>
#       1 from sklearn.metrics import classification_report,confusion_matrix
#       2
# ----> 3 print(classification_report(y_test,predictions))
#       4 print(confusion_matrix(y_test,predictions))
#
# NameError: name 'predictions' is not defined
