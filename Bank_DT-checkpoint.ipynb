# %% [markdown]
# # Using Decision Tree on Bank Dataset

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Reading the .csv file
df=pd.read_csv('Bank_Data.csv',sep=';')
df.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
#Using info() & describe() function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label (or using deletion or imputation techniques).

# %%
#Checking for null values
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# Knowing more about the data..............

# %%
#Converting age groups into sections
df_age=pd.DataFrame(df['age'],columns=['age'],dtype=str)
df_age[df['age']<=101]='60 to 100'
df_age[df['age']<=60]='30 to 60'
df_age[df['age']<=30]='0 to 30'
df_age.head(10)
# Out:
#         age
# 0  30 to 60
# 1  30 to 60
# 2  30 to 60
# 3  30 to 60
# 4  30 to 60
# 5  30 to 60
# 6  30 to 60
# 7  30 to 60
# 8   0 to 30
# 9   0 to 30

# %%
#Drawing a pie chart according to the age groups
print('Call Receivers Ages\n',df_age.value_counts())
plt.pie([7383,32895,910],labels=['0 to 30','30 to 60','60 to 100'],autopct='%2.2f%%')
plt.title('Age Groups of Call Receivers')
plt.show()
# Out:
# Call Receivers Ages
#  age
# 30 to 60     32895
# 0 to 30       7383
# 60 to 100      910
# dtype: int64

# %%
#Drawing a pie chart according to the 
jobs_count=df['job'].value_counts()
print(jobs_count)
f=plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.bar(jobs_count.index,jobs_count.values)
plt.title('Employement Status of the Call Receiver')
plt.show()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
#Checking how many people have a Loan from Bank
print('If the receiver has a Loan:')
print(df['loan'].value_counts())
plt.pie(df['loan'].value_counts().values,labels=df['loan'].value_counts().index,autopct='%2.2f%%')
plt.title('How many have Loan from any Bank:')
plt.show()
# Out:
# If the receiver has a Loan:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
#Checking how many said 'Yes for subscription' and 'No for subscription'
print('How many say Yes and No:')
print(df['y'].value_counts())
plt.pie(df['y'].value_counts().values,labels=df['y'].value_counts().index,autopct='%2.2f%%')
plt.title('How many have what response:')
plt.show()
# Out:
# How many say Yes and No:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# Applying Machine Learning Algorithm Decision Tree.......

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
#Saving in X and y
cols=['age','duration','campaign','pdays','previous','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']
X=df[cols]
y=df['y']
X.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -36.4      4.857       5191.0
# 1          -36.4      4.857       5191.0
# 2          -36.4      4.857       5191.0
# 3          -36.4      4.857       5191.0
# 4          -36.4      4.857       5191.0

# %%
y[y=='no']=0
y[y=='yes']=1
y=pd.to_numeric(y)
y
# Out:
# <ipython-input-162-c6c7496c3931>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y=='no']=0
# <ipython-input-162-c6c7496c3931>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y=='yes']=1
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y, Length: 41188, dtype: int64

# %%
#Checking for datatypes again

# %%
#Spliting the data......
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=46,test_size=0.3)

# %%
y_train.dtypes
# Out:
# dtype('int64')

# %%
#Importing necessary libraries
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
dc.fit(X_train,y_train)
predictions=dc.predict(X_test)

# %%
#Checking for accuracy
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     11011
#            1       0.50      0.54      0.52      1346
#
#     accuracy                           0.89     12357
#    macro avg       0.72      0.74      0.73     12357
# weighted avg       0.89      0.89      0.89     12357
#
# [[10287   724]
#  [  621   725]]
