# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import os
path=r'C:\Users\ANIL\Desktop\python\tree data structure'
os.chdir(path)

# %%
df=pd.read_csv('dataset123.csv')
df.head(30)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1     2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2     3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3     4.0      M  56.00      NaN  52.00  Central   Science     52.00
# 4     5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5     6.0      M  55.00   Others    NaN   Others   Science     67.25
# 6     NaN      F  46.00   Others  49.20   Others  Commerce     79.00
# 7     8.0      M  82.00  Central  64.00  Central   Science     66.00
# 8     9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 9     NaN      M  58.00      NaN  70.00  Central  Commerce     61.00
# 10   11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# 11   12.0      M  69.60  Central    NaN  Central  Commerce     78.30
# 12   13.0      F  47.00  Central  55.00   Others   Science       NaN
# 13   14.0      F  77.00      NaN  87.00  Central  Commerce     59.00
# 14    NaN      M  62.00  Central  47.00  Central  Commerce     50.00
# 15   16.0      F  65.00  Central  75.00  Central  Commerce     69.00
# 16   17.0      M  63.00  Central  66.20  Central  Commerce     65.60
# 17   18.0      F  55.00  Central    NaN  Central  Commerce     64.00
# 18    NaN      F  63.00      NaN  66.00  Central  Commerce     64.00
# 19   20.0      M  60.00   Others  67.00   Others      Arts     70.00
# 20   21.0      M  62.00   Others  65.00   Others  Commerce     66.00
# 21   22.0      F  79.00   Others    NaN   Others  Commerce     85.00
# 22   23.0      F  69.80   Others  60.80   Others   Science     72.23
# 23   24.0      F  77.40   Others  60.00   Others   Science     64.74
# 24    NaN      M  76.50      NaN  97.70   Others   Science     78.86
# 25   26.0      F  52.58   Others  54.60  Central  Commerce     50.20
# 26   27.0      M  71.00   Others  79.00   Others  Commerce     66.00
# 27    NaN      M  63.00   Others  67.00   Others  Commerce     66.00
# 28   29.0      M  76.76   Others    NaN   Others  Commerce     67.50
# 29   30.0      M  62.00      NaN    NaN  Central  Commerce       NaN
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary
# 0    Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1    Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2   Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3    Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4   Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5    Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6   Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7    Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8   Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9   Comm&Mgmt    NaN    54.00        Mkt&Fin  52.21  Not Placed       NaN
# 10  Comm&Mgmt    Yes    62.00         Mkt&HR  60.85      Placed  260000.0
# 11  Comm&Mgmt    Yes    60.00            NaN  63.70      Placed  250000.0
# 12  Comm&Mgmt     No    62.00         Mkt&HR  65.04  Not Placed       NaN
# 13  Comm&Mgmt     No    68.00        Mkt&Fin  68.63      Placed  218000.0
# 14  Comm&Mgmt     No    76.00         Mkt&HR    NaN         NaN       NaN
# 15  Comm&Mgmt    Yes    72.00            NaN  64.66      Placed  200000.0
# 16  Comm&Mgmt    Yes    60.00        Mkt&Fin  62.54      Placed  300000.0
# 17  Comm&Mgmt     No    60.00        Mkt&Fin  67.28  Not Placed       NaN
# 18  Comm&Mgmt     No      NaN         Mkt&HR    NaN         NaN       NaN
# 19  Comm&Mgmt    Yes    50.48        Mkt&Fin  77.89      Placed  236000.0
# 20  Comm&Mgmt     No    50.00            NaN  56.70      Placed  265000.0
# 21  Comm&Mgmt     No    95.00        Mkt&Fin  69.06      Placed  393000.0
# 22   Sci&Tech     No    55.53         Mkt&HR  68.81         NaN  360000.0
# 23   Sci&Tech    Yes    92.00        Mkt&Fin  63.62      Placed  300000.0
# 24   Sci&Tech     No    97.40        Mkt&Fin    NaN      Placed  360000.0
# 25  Comm&Mgmt    Yes    76.00            NaN  65.33  Not Placed       NaN
# 26  Comm&Mgmt    Yes    94.00        Mkt&Fin  57.55      Placed  240000.0
# 27  Comm&Mgmt     No    68.00         Mkt&HR  57.69      Placed  265000.0
# 28  Comm&Mgmt    Yes    73.35        Mkt&Fin  64.15      Placed  350000.0
# 29  Comm&Mgmt     No      NaN        Mkt&Fin  51.29  Not Placed       NaN

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  209.000000  215.000000  209.000000  213.000000  213.000000  212.000000
# mean   110.602871   67.303395   66.301100   66.415915   72.096808   62.248868
# std     61.123301   10.827205   10.949664    7.370247   13.331212    5.795673
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     59.000000   60.600000   60.800000   61.000000   60.000000   57.967500
# 50%    111.000000   67.000000   65.000000   66.000000   71.000000   61.950000
# 75%    163.000000   75.700000   73.000000   72.000000   84.000000   66.242500
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           209 non-null    float64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           209 non-null    object
#  4   hsc_p           209 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        213 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          214 non-null    object
#  10  etest_p         213 non-null    float64
#  11  specialisation  211 non-null    object
#  12  mba_p           212 non-null    float64
#  13  status          212 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 25.3+ KB

# %%
df.dropna(axis=1)
# Out:
#     gender  ssc_p    hsc_b     hsc_s   degree_t
# 0        M  67.00   Others  Commerce   Sci&Tech
# 1        M  79.33   Others   Science   Sci&Tech
# 2        M  65.00  Central      Arts  Comm&Mgmt
# 3        M  56.00  Central   Science   Sci&Tech
# 4        M  85.80  Central  Commerce  Comm&Mgmt
# ..     ...    ...      ...       ...        ...
# 210      M  80.60   Others  Commerce  Comm&Mgmt
# 211      M  58.00   Others   Science   Sci&Tech
# 212      M  67.00   Others  Commerce  Comm&Mgmt
# 213      F  74.00   Others  Commerce  Comm&Mgmt
# 214      M  62.00   Others   Science  Comm&Mgmt
#
# [215 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl_no              6
# gender             0
# ssc_p              0
# ssc_b              6
# hsc_p              6
# hsc_b              0
# hsc_s              0
# degree_p           2
# degree_t           0
# workex             1
# etest_p            2
# specialisation     4
# mba_p              3
# status             3
# salary            67
# dtype: int64

# %%
#finding mean values,since there are null values and some of the vlaues need to be replaced.
df.mean()
# Out:
# sl_no          110.602871
# ssc_p           67.303395
# hsc_p           66.301100
# degree_p        66.415915
# etest_p         72.096808
# mba_p           62.248868
# salary      288655.405405
# dtype: float64

# %%
#filling the missing values
df['ssc_p'].fillna(df['ssc_p'].mean())
# Out:
# 0      67.00
# 1      79.33
# 2      65.00
# 3      56.00
# 4      85.80
#        ...
# 210    80.60
# 211    58.00
# 212    67.00
# 213    74.00
# 214    62.00
# Name: ssc_p, Length: 215, dtype: float64

# %%
df['degree_p'].fillna(df['degree_p'].mean())
# Out:
# 0      58.00
# 1      77.48
# 2      64.00
# 3      52.00
# 4      73.30
#        ...
# 210    77.60
# 211    72.00
# 212    73.00
# 213    58.00
# 214    53.00
# Name: degree_p, Length: 215, dtype: float64

# %%
df['hsc_p'].fillna(df['hsc_p'].mean())
# Out:
# 0      91.00
# 1      78.33
# 2      68.00
# 3      52.00
# 4      73.60
#        ...
# 210    82.00
# 211    60.00
# 212    67.00
# 213    66.00
# 214    58.00
# Name: hsc_p, Length: 215, dtype: float64

# %%
df['etest_p'].fillna(df['etest_p'].mean())
# Out:
# 0      55.0
# 1      86.5
# 2      75.0
# 3      66.0
# 4      96.8
#        ...
# 210    91.0
# 211    74.0
# 212    59.0
# 213    70.0
# 214    89.0
# Name: etest_p, Length: 215, dtype: float64

# %%
df['mba_p'].fillna(df['mba_p'].mean())
# Out:
# 0      58.80
# 1      66.28
# 2      57.80
# 3      59.43
# 4      55.50
#        ...
# 210    74.49
# 211    53.62
# 212    69.72
# 213    60.23
# 214    60.22
# Name: mba_p, Length: 215, dtype: float64

# %%
df['salary'].fillna(df['salary'].mean())
# Out:
# 0      270000.000000
# 1      200000.000000
# 2      250000.000000
# 3      288655.405405
# 4      425000.000000
#            ...
# 210    400000.000000
# 211    275000.000000
# 212    295000.000000
# 213    204000.000000
# 214    288655.405405
# Name: salary, Length: 215, dtype: float64

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1    2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2    3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3    4.0      M  56.00      NaN  52.00  Central   Science     52.00
# 4    5.0      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.gender
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 210    M
# 211    M
# 212    M
# 213    F
# 214    M
# Name: gender, Length: 215, dtype: object

# %%
df.dropna(subset=['gender', 'ssc_b','hsc_b','hsc_s','degree_t','specialisation'])
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6.0      M  55.00   Others    NaN   Others   Science     67.25
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 211  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 212  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 213  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 214  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# 5     Sci&Tech    Yes     55.0        Mkt&Fin  51.58  Not Placed       NaN
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [205 rows x 15 columns]

# %%
def gender(x):
        if x=='F':
             return 1
        if x=='M':
             return 0

# %%
df['gender']=df['gender'].apply(gender)
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1.0       0  67.00      1  91.00      1      1     58.00         2
# 1      2.0       0  79.33      0  78.33      1      2     77.48         2
# 2      3.0       0  65.00      0  68.00      0      0     64.00         0
# 3      4.0       0  56.00      2  52.00      0      2     52.00         2
# 4      5.0       0  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210  211.0       0  80.60      1  82.00      1      1     77.60         0
# 211  212.0       0  58.00      1  60.00      1      2     72.00         2
# 212  213.0       0  67.00      1  67.00      1      1     73.00         0
# 213  214.0       1  74.00      1  66.00      1      1     58.00         0
# 214  215.0       0  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status    salary
# 0         0     55.0               1  58.80       1  270000.0  0
# 1         1     86.5               0  66.28       1  200000.0  0
# 2         0     75.0               0  57.80       1  250000.0  0
# 3         0     66.0               1  59.43       0       NaN  0
# 4         0     96.8               0  55.50       1  425000.0  0
# ..      ...      ...             ...    ...     ...       ... ..
# 210       0     91.0               0  74.49       1  400000.0  0
# 211       0     74.0               0  53.62       1  275000.0  0
# 212       1     59.0               0  69.72       1  295000.0  0
# 213       0     70.0               1  60.23       1  204000.0  1
# 214       0     89.0               1  60.22       0       NaN  0
#
# [215 rows x 16 columns]

# %%
#to convert string to float and to 0 , 1 , ... in a single code
label_encoder = preprocessing.LabelEncoder()
def strTofloat(col):
    df[col]= label_encoder.fit_transform(df[col])
    df[col].unique()
df.columns
strTofloat('hsc_b')
strTofloat('hsc_s')
strTofloat('degree_t')
strTofloat('workex')
strTofloat('specialisation')
strTofloat('status')

# %%
df['ssc_b'].unique()
# Out:
# array(['Others', 'Central', nan], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['ssc_b']= label_encoder.fit_transform(df['ssc_b'])
df['ssc_b'].unique()
# Out:
# array([1, 0, 2])

# %%
df['hsc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['hsc_b']= label_encoder.fit_transform(df['hsc_b'])
df['hsc_b'].unique()
# Out:
# array([1, 0])

# %%
df['degree_t'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['degree_t']= label_encoder.fit_transform(df['degree_t'])
df['degree_t'].unique()
# Out:
# array([2, 0, 1])

# %%
df['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin', nan], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['specialisation']= label_encoder.fit_transform(df['specialisation'])
df['specialisation'].unique()
# Out:
# array([1, 0, 2])

# %%
df['status'].unique()
# Out:
# array(['Placed', 'Not Placed', nan], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['status']= label_encoder.fit_transform(df['status'])
df['status'].unique()
# Out:
# array([1, 0, 2])

# %%
df['hsc_s'].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['hsc_s']= label_encoder.fit_transform(df['hsc_s'])
df['hsc_s'].unique()
# Out:
# array([1, 2, 0])

# %%
df['workex'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['workex']= label_encoder.fit_transform(df['workex'])
df['workex'].unique()
# Out:
# array([0, 1, 2])

# %%
#conversion from string to float
df['salary'] = df['salary'].astype(float)

# %%
df['salary'].astype(float)
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           NaN
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         NaN
# Name: salary, Length: 215, dtype: float64

# %%
df['gender'] = df['gender'].astype(float)

# %%
df.dropna(axis=1)
# Out:
#      gender  ssc_p  ssc_b  hsc_b  hsc_s  degree_t  workex  specialisation  \
# 0       0.0  67.00      1      1      1         2       0               1
# 1       0.0  79.33      0      1      2         2       1               0
# 2       0.0  65.00      0      0      0         0       0               0
# 3       0.0  56.00      2      0      2         2       0               1
# 4       0.0  85.80      0      0      1         0       0               0
# ..      ...    ...    ...    ...    ...       ...     ...             ...
# 210     0.0  80.60      1      1      1         0       0               0
# 211     0.0  58.00      1      1      2         2       0               0
# 212     0.0  67.00      1      1      1         0       1               0
# 213     1.0  74.00      1      1      1         0       0               1
# 214     0.0  62.00      0      1      2         0       0               1
#
#      status
# 0         1  0
# 1         1  0
# 2         1  0
# 3         0  0
# 4         1  0
# ..      ... ..
# 210       1  0
# 211       1  0
# 212       1  0
# 213       1  1
# 214       0  0
#
# [215 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# sl_no              6
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              6
# hsc_b              0
# hsc_s              0
# degree_p           2
# degree_t           0
# workex             0
# etest_p            2
# specialisation     0
# mba_p              3
# status             0
# salary            67
#                    0
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)

# %%
df.shape
# Out:
# (143, 16)

# %%
df_age=pd.DataFrame(df['ssc_p'],columns=['ssc_p'],dtype=str)
df_age[df['ssc_p']<=101]='70 to 100'
df_age[df['ssc_p']<=70]='30 to 70'
df_age[df['ssc_p']<=30]='0 to 30'
df_age.head(10)
# Out:
#         ssc_p
# 0    30 to 70
# 1   70 to 100
# 2    30 to 70
# 4   70 to 100
# 7   70 to 100
# 8   70 to 100
# 10   30 to 70
# 13  70 to 100
# 15   30 to 70
# 16   30 to 70

# %%
df_age=pd.DataFrame(df['etest_p'],columns=['etest_p'],dtype=str)
df_age[df['etest_p']<=101]='70 to 100'
df_age[df['etest_p']<=70]='30 to 70'
df_age[df['etest_p']<=30]='0 to 30'
df_age.head(10)
# Out:
#       etest_p
# 0    30 to 70
# 1   70 to 100
# 2   70 to 100
# 4   70 to 100
# 7    30 to 70
# 8   70 to 100
# 10   30 to 70
# 13   30 to 70
# 15  70 to 100
# 16   30 to 70

# %%
print('mba_p\n',df_age.value_counts())
# Out:
# mba_p
#  etest_p
# 70 to 100    76
# 30 to 70     67
# dtype: int64

# %%
plt.pie([75,64],labels=['70 to 100','30 to 70'],autopct='%2.2f%%')
plt.title('MBA PERCENTAGE')
plt.show()

# %%
hsc_s_count=df['hsc_s'].value_counts()
print(hsc_s_count)
f=plt.figure()
f.set_figwidth(8)
f.set_figheight(4)
plt.bar(hsc_s_count.index,hsc_s_count.values)
plt.title('hsc_s')
plt.show()
# Out:
# 1    75
# 2    62
# 0     6
# Name: hsc_s, dtype: int64

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary', ''],
#       dtype='object')

# %%
y = df['salary']

# %%
X = df[['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
       'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
       'status']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 4.72952742e+01 -5.62235106e+04 -2.41229369e+02  7.23771433e+03
#  -9.45233841e+02 -3.43291496e+04  1.29877101e+04 -2.35969134e+03
#   1.30749116e+04  4.53151763e+03  4.80880062e+02 -1.80456034e+04
#   4.37792596e+03  9.40514406e+04]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 65565.1679092939
# MSE: 8939322465.565783
# RMSE: 94547.99027777261

# %%
sns.distplot((y_test-predictions),bins=20);
# Out:
# C:\Users\ANIL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                  Coeffecient
# sl_no              47.295274
# gender         -56223.510613
# ssc_p            -241.229369
# ssc_b            7237.714334
# hsc_p            -945.233841
# hsc_b          -34329.149624
# hsc_s           12987.710102
# degree_p        -2359.691345
# degree_t        13074.911597
# workex           4531.517632
# etest_p           480.880062
# specialisation -18045.603396
# mba_p            4377.925960
# status          94051.440600
